# %%
import numpy as np
import networkx as nx

import matplotlib.pyplot as plt
from graphtda import FilteredGraph

# %%
edgelist = [(0, 3), (0, 4), (1, 6), (1, 7), (1, 3), (2, 9), (2, 8), (3, 9), (3, 6), (3, 5), (4, 5), (4, 6), (5, 8), (5, 6), (6, 3), (6, 9), (7, 5), (8, 3), (8, 7), (9, 8), (9, 5), (9, 7)]
G = nx.Graph()
G.add_edges_from(edgelist)
fig, ax = plt.subplots(1, figsize=(4,4))
nx.draw_networkx(G, pos=nx.spring_layout(G, seed=2), ax=ax)

# %%
from graphtda import HKS_bifiltration
FG = FilteredGraph(G, filtration_function=HKS_bifiltration)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from graphtda import HKS_bifiltration
#       2 FG = FilteredGraph(G, filtration_function=HKS_bifiltration)
#
# ImportError: cannot import name 'HKS_bifiltration' from 'graphtda' (/home/niklas/Documents/graphtda/graphtda/__init__.py)
